# %% [markdown]
# <a href="https://colab.research.google.com/github/segmue/Geo871_geoparsing_example/blob/main/GEO871_geoparser_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Example Code Different Location Reference Recognitions
#
# This notebook contains sample code for the following methods:
# - a simple gazetteer lookup
# - using spaCy Natural Language Processing Models (NLP)
# - geoparser package
#
#
# geoparser is a quite new package developed during a GIUZ Master Thesis.
# It is a hybrid approach, using a global gazeteer (geonames), a NLP (spaCy) and a transformer deep learning architecture.
#
# **Important Note: The first two code blocks need ~15 Minutes to load, start them early**
#
#
# (https://github.com/dguzh/geoparser)

# %%
# %%capture
# !pip install geoparser
# !pip install geopandas
# !pip install mapclassify
# !python -m spacy download en_core_web_sm
# !python -m spacy download de_core_news_sm

# %% [markdown]
# Next, the code below downloads the geonames gazeteer (worldwide) and loads it in a SQL database. Smaller, or local gazeteers are not natively supported yet (This part downloads ca. 5 GB data, so give it some time)

# %%
# !python -m geoparser download geonames
# Out:
# 2024-10-23 07:13:27.574490: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-23 07:13:27.597282: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-23 07:13:27.605485: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-23 07:13:27.622379: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-23 07:13:29.551382: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Database setup...
# Downloading allCountries.zip: 100% 384M/384M [00:13<00:00, 30.8MiB/s]
# Downloading alternateNames.zip: 100% 182M/182M [00:06<00:00, 28.1MiB/s]
# Downloading admin1CodesASCII.txt: 100% 144k/144k [00:00<00:00, 401kiB/s]
# Downloading admin2Codes.txt: 100% 2.24M/2.24M [00:00<00:00, 3.56MiB/s]
# Downloading countryInfo.txt: 100% 30.9k/30.9k [00:00<00:00, 347kiB/s]
# Downloading featureCodes_en.txt: 100% 57.3k/57.3k [00:00<00:00, 319kiB/s]
# Loading allCountries:  25% 33/130 [01:01<03:02,  1.88s/it]
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/usr/local/lib/python3.10/dist-packages/geoparser/__main__.py", line 32, in <module>
#     main(args)
#   File "/usr/local/lib/python3.10/dist-packages/geoparser/__main__.py", line 27, in main
#     gazetteer.setup_database()
#   File "/usr/local/lib/python3.10/dist-packages/geoparser/geonames.py", line 27, in setup_database
#     self.load_data()
#   File "/usr/local/lib/python3.10/dist-packages/geoparser/geonames.py", line 87, in load_data
#     self.populate_tables(conn)
#   File "/usr/local/lib/python3.10/dist-packages/geoparser/geonames.py", line 216, in populate_tables
#     self.load_file_into_table(
#   File "/usr/local/lib/python3.10/dist-packages/geoparser/geonames.py", line 351, in load_file_into_table
#     chunk.to_sql(table_name, conn, if_exists="append", index=False)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 333, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/generic.py", line 3087, in to_sql
#     return sql.to_sql(
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/sql.py", line 842, in to_sql
#     return pandas_sql.to_sql(
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/sql.py", line 2851, in to_sql
#     return table.insert(chunksize, method)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/sql.py", line 1119, in insert
#     num_inserted = exec_insert(conn, keys, chunk_iter)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/sql.py", line 2547, in _execute_insert
#     conn.executemany(self.insert_statement(num_rows=1), data_list)
# KeyboardInterrupt
# ^C

# %%
while True:
  pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-648a2bab0435> in <cell line: 1>()
# ----> 1 while True:
#       2   pass
#
# KeyboardInterrupt:

# %% [markdown]
# ## Swissnames3D Gazetteer Lookup

# %% [markdown]
# #### Introduction:
# This task should show the limitations and possibilities of using a gazetteer (e.g. a list of placenames) for location reference recognition. For this, we will use a lightweight version of Swissnames3D. All rows in the original gazetter (which would also contain geometries) were just grouped by name and their occurances counted.
#
#
# #### Here are some possible tasks:
# - Test the 'lookup_words_in_gazeteer' function with different sentences, what do you notice? Can you find the strangest placename in a swiss gazetteer?
# - Which five placenames have the highest occurance in the swiss gazetteer?
# - How many times does 'Zürich' occur in the gazetteer? What about alternative ways of spelling Zürich or as part of a whole string? (e.g. "Zürich HB")

# %%
import pandas as pd
swissnames = pd.read_csv('https://raw.githubusercontent.com/segmue/Geo871_geoparsing_example/af77e1653b92919eba234c793bb021dc190bbb7d/swissnames_dict.csv')
swissnames = dict(zip(swissnames.Name, swissnames.Count))

# %%
def lookup_words_in_gazeteer(strings):
  if not isinstance(strings, list):
    strings = [strings]
  counter = 0
  for string in strings:
      counter += 1
      words = string.split()
      ## Make found words a tuple, containing the dict Key and Value
      found_words = [(word, swissnames[word.lower()]) for word in words if word.lower() in swissnames]

      #found_words = [word for word in words if word.lower() in swissnames]
      print(f'Sample {counter} ------------')
      print(f"Placenames: {found_words}")

# %%
examples = ['Vom Bahnhof Buchs aus nehme ich den Zug nach Zürich',
            'Hier steht ein beispielhafter Satz',
            'neue sätze schreiben']

match_words_with_gazeteer(examples)
# Out:
# Sample 1 ------------
# Placenames: [('Bahnhof', 8), ('Buchs', 13), ('Zug', 15), ('Zürich', 2)]
# Sample 2 ------------
# Placenames: [('Satz', 9)]

# %% [markdown]
# ## Example using SpaCy
#
# #### Introduction
# This time, we're using a pretrained language model to recognize locations in text. Spacy flags basically every wort in the sentence with a label. We're looking for entities, which have label LOC (Location), GPE (Geo-Political Entity) or FAC (Facility).
# The next code blocks are either for English Language or German. Use whatever you like.
#
# #### Task:
# - Again, test different sentences. Is it better than the gazetter lookup?
# - Which of the two methods do you think would have a higher precision value? Which has higher recall values?

# %%
## English Language Model
import spacy

nlp = spacy.load("en_core_web_sm")

def find_locations(texts):
    for i, text in enumerate(texts, 1):
        doc = nlp(text)
        locations = [ent.text for ent in doc.ents if ent.label_ in {"LOC", "FAC", "GPE"}]
        print(f"text {i} ------")
        print(f"Locations: {locations if locations else 'None found'}\n")

# Example usage:
texts = [
    "Each morning, I walk to the Train Station in Chelsea, and take the train to Greenwich. The train even drives to Westminster and Brixton.",
    "There is a small town near the mountains.",
    "Berlin is the capital of Germany.",
    "Interestingly, the city of Bath in Somerset was founded by the Roman Empire, because of the hot springs."
]

find_locations(texts)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-3df5c3f71cb0> in <cell line: 2>()
#       1 ## English Language Model
# ----> 2 import spacy
#       3
#       4 nlp = spacy.load("en_core_web_sm")
#       5
#
# /usr/local/lib/python3.10/dist-packages/spacy/__init__.py in <module>
#       4
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       7
#       8 setup_default_warnings()  # noqa: E402
#
# /usr/local/lib/python3.10/dist-packages/spacy/errors.py in <module>
#       1 import warnings
#       2
# ----> 3 from .compat import Literal
#       4
#       5
#
# /usr/local/lib/python3.10/dist-packages/spacy/compat.py in <module>
#       2 import sys
#       3
# ----> 4 from thinc.util import copy_array
#       5
#       6 try:
#
# /usr/local/lib/python3.10/dist-packages/thinc/__init__.py in <module>
#       3
#       4 from .about import __version__
# ----> 5 from .config import registry
#       6
#       7 # fmt: off
#
# /usr/local/lib/python3.10/dist-packages/thinc/config.py in <module>
#       3 from confection import VARIABLE_RE, Config, ConfigValidationError, Promise
#       4
# ----> 5 from .types import Decorator
#       6
#       7
#
# /usr/local/lib/python3.10/dist-packages/thinc/types.py in <module>
#      23 import numpy
#      24
# ---> 25 from .compat import cupy, has_cupy
#      26
#      27 if has_cupy:
#
# /usr/local/lib/python3.10/dist-packages/thinc/compat.py in <module>
#      33
#      34 try:  # pragma: no cover
# ---> 35     import torch
#      36     import torch.utils.dlpack
#      37
#
# /usr/local/lib/python3.10/dist-packages/torch/__init__.py in <module>
#     288     if USE_GLOBAL_DEPS:
#     289         _load_global_deps()
# --> 290     from torch._C import *  # noqa: F403
#     291
#     292 # Appease the type checker; ordinarily this binding is inserted by the
#
# KeyboardInterrupt:

# %%
## German Language Model

import spacy

nlp = spacy.load("de_core_news_sm")

def find_locations(texts):
    for i, text in enumerate(texts, 1):
        doc = nlp(text)
        locations = [ent.text for ent in doc.ents if ent.label_ in {"LOC", "FAC", "GPE"}]
        print(f"text {i} ------")
        print(f"Locations: {locations if locations else 'None found'}\n")

# Example usage:
texts = [
    "Each morning, I walk to the Train Station in Chelsea, and take the train to Greenwich. The train even drives to Westminster and Brixton.",
    "There is a small town near the mountains.",
    "Berlin is the capital of Germany.",
    "Interestingly, the city of Bath in Somerset was founded by the Roman Empire, because of the hot springs."
]

find_locations(texts)

# %% [markdown]
# ## Setting up the Geoparser
#
# - We load a lightweight language model from spacy.
# - The transformer model is a pre-trained Deep Learning Model.
# - The Gazeteer is the database known placenames-

# %%
from geoparser import Geoparser

geo = Geoparser(spacy_model='en_core_web_sm', transformer_model='dguzh/geo-all-MiniLM-L6-v2', gazetteer='geonames')
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/741 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# ## Exercise:
# Here you have some example texts.
# You can use these first examples to test the location reference recognition.
#
# Task1:
# - Run the code below and the next chunk. The output should be a list of recognized toponyms in the document. Are all locations recognized? Why not?
#
# - Test some different sentences or phrasing. Does the parser recognize all your locations?
#
#
# Task2 (voluntarily):
# - Use the map_toponyms function to look at the fully geocoded locations in the map. Change the sentences as you like and see how the geocoder works.

# %%
def print_toponyms(text):
  if not isinstance(text, list):
    text = [text]
  parsed_docs = geo.parse(text)
  counter = 0
  for doc in parsed_docs:
    print(f"Sample {counter} ------------")
    counter += 1
    for toponym in doc.toponyms:
        print(toponym)
        if toponym.location:
            print(toponym.location['latitude'], toponym.location['longitude'])
        else:
            print("No location found")

# %%
text_samples = [
    "I love to buy Pork in York, New Yorkshire. But the ham in New York is also lovely",
    "Arabic is the 6th most common language in the United States",
    "Interestingly, the city of Bath in Somerset was founded by the Roman Empire, because of the hot springs."
    "I think I'll take a Bath today"
]
print_toponyms(text_samples)
# Out:
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Batches:   0%|          | 0/31 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Sample 0 ------------
# York
# 53.95763 -1.08271
# New Yorkshire
# 54.44158 -1.91088
# New York
# 55.02485 -1.48619
# Sample 1 ------------
# the United States
# 18.34829 -64.98348
# Sample 2 ------------
# Somerset
# 51.08333 -3.0
# the Roman Empire
# No location found

# %%
import geopandas as gpd
from shapely.geometry import Point

def map_toponyms(docs):
    all_toponyms = []

    for counter, doc in enumerate(geo.parse(docs), start=1):
        for toponym in doc.toponyms:
            if toponym.location:
                latitude = toponym.location['latitude']
                longitude = toponym.location['longitude']

                toponym_data = {
                    'name': toponym,
                    'sample_number': counter,
                    'geometry': Point(longitude, latitude)
                }
                all_toponyms.append(toponym_data)

    gdf = gpd.GeoDataFrame(all_toponyms, crs="EPSG:4326")
    return gdf.explore(marker_type="marker")

# %%
map_toponyms(text_samples)
# Out:
# Toponym Recognition...
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Toponym Resolution...
# Batches:   0%|          | 0/31 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc446777cf0d50a7d66aaa265bbd7dbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc446777cf0d50a7d66aaa265bbd7dbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc446777cf0d50a7d66aaa265bbd7dbb = L.map(
#                 &quot;map_fc446777cf0d50a7d66aaa265bbd7dbb&quot;,
#                 {
#                     center: [36.68657, -33.033095],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_fc446777cf0d50a7d66aaa265bbd7dbb);
#
#
#
#
#
#             var tile_layer_6033d69f573930e7367cd4a5720f1e42 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6033d69f573930e7367cd4a5720f1e42.addTo(map_fc446777cf0d50a7d66aaa265bbd7dbb);
#
#
#             map_fc446777cf0d50a7d66aaa265bbd7dbb.fitBounds(
#                 [[18.34829, -64.98348], [55.02485, -1.08271]],
#                 {}
#             );
#
#
#         function geo_json_03ca3784e9f8db6fca59fd935590f82c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_03ca3784e9f8db6fca59fd935590f82c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_03ca3784e9f8db6fca59fd935590f82c_pointToLayer(feature, latlng) {
#             var opts = {&quot;fill&quot;: true, &quot;radius&quot;: 2};
#
#             let style = geo_json_03ca3784e9f8db6fca59fd935590f82c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.Marker(latlng, opts)
#         }
#
#         function geo_json_03ca3784e9f8db6fca59fd935590f82c_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_03ca3784e9f8db6fca59fd935590f82c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_03ca3784e9f8db6fca59fd935590f82c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_03ca3784e9f8db6fca59fd935590f82c = L.geoJson(null, {
#                 onEachFeature: geo_json_03ca3784e9f8db6fca59fd935590f82c_onEachFeature,
#
#                 style: geo_json_03ca3784e9f8db6fca59fd935590f82c_styler,
#                 pointToLayer: geo_json_03ca3784e9f8db6fca59fd935590f82c_pointToLayer,
#         });
#
#         function geo_json_03ca3784e9f8db6fca59fd935590f82c_add (data) {
#             geo_json_03ca3784e9f8db6fca59fd935590f82c
#                 .addData(data);
#         }
#             geo_json_03ca3784e9f8db6fca59fd935590f82c_add({&quot;bbox&quot;: [-64.98348, 18.34829, -1.08271, 55.02485], &quot;features&quot;: [{&quot;bbox&quot;: [-1.08271, 53.95763, -1.08271, 53.95763], &quot;geometry&quot;: {&quot;coordinates&quot;: [-1.08271, 53.95763], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;York&quot;, &quot;sample_number&quot;: 1}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-1.91088, 54.44158, -1.91088, 54.44158], &quot;geometry&quot;: {&quot;coordinates&quot;: [-1.91088, 54.44158], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;New Yorkshire&quot;, &quot;sample_number&quot;: 1}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-1.48619, 55.02485, -1.48619, 55.02485], &quot;geometry&quot;: {&quot;coordinates&quot;: [-1.48619, 55.02485], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;New York&quot;, &quot;sample_number&quot;: 1}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-64.98348, 18.34829, -64.98348, 18.34829], &quot;geometry&quot;: {&quot;coordinates&quot;: [-64.98348, 18.34829],
